# %%
#add in list
a =[1,5,44,348,40,4]
li=[]
od_li=[]
cout_even=0
cout_odd=0
for i in a:
  if i % 2 ==0:
    li.append(i)
    cout_even=cout_odd+1
  else:
    od_li.append(i)
    cout_odd= cout_odd+1
print(li)
print(cout_even)
print(od_li)
print(cout_odd)
# Out:
# [44, 348, 40, 4]
# 3
# [1, 5]
# 2
